# %% [markdown]
# <a href="https://colab.research.google.com/github/LeelakrishnThummala/ML_HW2/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_gradientof_Cubic(Learning_Rate, epochs, X,Y):
  #Initialize Parameters
  v,w,y,z= 0,0,0,0
  Lr = Learning_Rate
  y_pred = v*X**3 +w*X**2+y*X+z
  n = len(X)
  for i in range(epochs):
    y_pred = v*(X**3) + w*(X**2)+y*X+z
    #performing gradient descent
    partialDerivative_v = (-2/n)*sum(X*(Y-y_pred))
    partialDerivative_w = (-2/n)*sum(X*(Y-y_pred))
    partialDerivative_y = (-2/n)*sum(X*(Y-y_pred))
    partialDerivative_z= (-2/n)*sum((Y-y_pred))
    v = v-(Lr*partialDerivative_v)
    w = w-(Lr*partialDerivative_w)
    y = y-(Lr*partialDerivative_y)
    z = z-(Lr*partialDerivative_z)
  return y_pred
  #load data
data_ = pd.read_csv("/content/HW2_nonlinear_data.csv",header=0)
arr_X = data_["X"].values
arr_Y = data_["Y"].values
#make predictions
pred_y = calculate_gradientof_Cubic(0.000001,10000,arr_X,arr_Y)
#visualize results
plt.scatter(arr_X,arr_Y)
plt.scatter(arr_X,pred_y,10,color='red')
