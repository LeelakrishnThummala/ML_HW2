# %% [markdown]
# <a href="https://colab.research.google.com/github/LeelakrishnThummala/ML_HW2/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/HW2_linear_data.csv')

# %%
data = pd.read_csv('/content/HW2_linear_data.csv')
X = data['X'].values
Y = data['Y'].values

# %%
data
# Out:
#             X          Y
# 0   32.502345  31.707006
# 1   53.426804  68.777596
# 2   61.530358  62.562382
# 3   47.475640  71.546632
# 4   59.813208  87.230925
# ..        ...        ...
# 95  50.030174  81.536991
# 96  49.239765  72.111832
# 97  50.039576  85.232007
# 98  48.149859  66.224958
# 99  25.128485  53.454394
#
# [100 rows x 2 columns]

# %%
# Initialize parameters (m and c)
m = 0
c = 0

# Hyperparameters
learning_rate = 0.0001
epochs = 1000

# %%
def mse_loss(Y, Y_pred):
    return ((Y - Y_pred) ** 2).mean()

# Lists to store loss values for plotting
loss_history = []

# Training the model using gradient descent
for epoch in range(epochs):
    # Calculate predictions
    Y_pred = m * X + c

    # Calculate the gradient of the loss with respect to m and c
    dm = (-2 / len(X)) * np.sum(X * (Y - Y_pred))
    dc = (-2 / len(X)) * np.sum(Y - Y_pred)

    # Update parameters using gradient descent
    m -= learning_rate * dm
    c -= learning_rate * dc

    # Calculate and store the current loss
    loss = mse_loss(Y, Y_pred)
    loss_history.append(loss)

# Plot the data points and the linear regression line
plt.scatter(X, Y, label='Data Points')
plt.plot(X, m * X + c, color='red', label='Linear Regression Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression using Gradient Descent')
plt.legend()

# Show the plot
plt.show()

# Print the final values of m and c
print(f'Final value of m: {m}')
print(f'Final value of c: {c}')

# Print the final MSE loss
final_loss = loss_history[-1]
print(f'Final MSE loss: {final_loss}')
# Out:
# Final value of m: 1.4777440851889796
# Final value of c: 0.08893651996682014
# Final MSE loss: 112.61484568814038
